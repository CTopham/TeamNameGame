# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

def pink_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(312, 100%%, %d%%)" % random.randint(40,100)

d = path.dirname('.')

text = open(path.join(d, 'top20female2010.txt')).read()

baby_mask = np.array(Image.open(path.join(d, "heart.png")))

wc = WordCloud(background_color="white", max_words=2000, mask=baby_mask,
               )
# generate word cloud
wc.generate(text)

# show
plt.imshow(wc.recolor(color_func=pink_color_func, random_state=3), interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(baby_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()

# store to file
wc.to_file(path.join(d, "top20female2010.png"))

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

def pink_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(240, 100%%, %d%%)" % random.randint(40,100)

d = path.dirname('.')

text = open(path.join(d, 'top20male1940.txt')).read()

baby_mask = np.array(Image.open(path.join(d, "star.png")))

wc = WordCloud(background_color="white", max_words=2000, mask=baby_mask,
               )
# generate word cloud
wc.generate(text)

# show
plt.imshow(wc.recolor(color_func=pink_color_func, random_state=3), interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(baby_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()

# store to file
wc.to_file(path.join(d, "top20male1940.png"))

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

files = ["top20male1880.txt", "top20male1890.txt", "top20male1900.txt", "top20male1910.txt", "top20male1920.txt",
        "top20male1930.txt", "top20male1940.txt", "top20male1950.txt", "top20male1960.txt", "top20male1970.txt", 
        "top20male1980.txt", "top20male1990.txt", "top20male2000.txt", "top20male2010.txt"]

def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(240, 100%%, %d%%)" % random.randint(40,100)

d = path.dirname('.')

for i in files:
    text = open(path.join(d, i)).read()

    baby_mask = np.array(Image.open(path.join(d, "star.png")))

    wc = WordCloud(background_color="white", max_words=2000, mask=baby_mask,
               )
    # generate word cloud
    wc.generate(text)

    # show
    plt.imshow(wc.recolor(color_func=color_func, random_state=3), interpolation='bilinear')
    plt.axis("off")
    plt.figure()
    plt.imshow(baby_mask, cmap=plt.cm.gray, interpolation='bilinear')
    plt.axis("off")
    plt.show()

    # store to file
    wc.to_file(path.join(d, i+".png"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-161-5ed33745b55e> in <module>()
#      15
#      16 for i in files:
# ---> 17     text = open(path.join(d, i)).read()
#      18
#      19     baby_mask = np.array(Image.open(path.join(d, "star.png")))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'top20male1920.txttop20male1930.txt'

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

files = ["top20female1880.txt", "top20female1890.txt", "top20female1900.txt", "top20female1910.txt", "top20female1920.txt",
        "top20female1930.txt", "top20female1940.txt", "top20female1950.txt", "top20female1960.txt", "top20female1970.txt", 
        "top20female1980.txt", "top20female1990.txt", "top20female2000.txt", "top20female2010.txt"]

def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(312, 100%%, %d%%)" % random.randint(40,100)

d = path.dirname('.')

for i in files:
    text = open(path.join(d, i)).read()

    baby_mask = np.array(Image.open(path.join(d, "heart.png")))

    wc = WordCloud(background_color="white", max_words=2000, mask=baby_mask,
               )
    # generate word cloud
    wc.generate(text)

    # show
    plt.imshow(wc.recolor(color_func=color_func, random_state=3), interpolation='bilinear')
    plt.axis("off")
    plt.figure()
    plt.imshow(baby_mask, cmap=plt.cm.gray, interpolation='bilinear')
    plt.axis("off")
    plt.show()

    # store to file
    wc.to_file(path.join(d, i+".png"))
